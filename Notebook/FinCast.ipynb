# %% [markdown]
# <a href="https://colab.research.google.com/github/mokuda2/hacklytics/blob/main/FinCast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to FinCast!
#
# In this notebook we create a model to forcast stock prices in order to gain profits.

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yfinance
#   Downloading yfinance-0.2.11-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 2.7 MB/s eta 0:00:00
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.3.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 KB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.8/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from yfinance) (1.3.5)
# Collecting beautifulsoup4>=4.11.1
#   Downloading beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 16.0 MB/s eta 0:00:00
# Collecting requests>=2.26
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 5.7 MB/s eta 0:00:00
# Collecting cryptography>=3.3.2
#   Downloading cryptography-39.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 60.6 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.8/dist-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.8/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.8/dist-packages (from yfinance) (1.21.6)
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.8/dist-packages (from yfinance) (4.9.2)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.8/dist-packages (from html5lib>=1.1->yfinance) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Installing collected packages: soupsieve, requests, html5lib, frozendict, cryptography, beautifulsoup4, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: html5lib
#     Found existing installation: html5lib 1.0.1
#     Uninstalling html5lib-1.0.1:
#       Successfully uninstalled html5lib-1.0.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed beautifulsoup4-4.11.2 cryptography-39.0.1 frozendict-2.3.4 html5lib-1.1 requests-2.28.2 soupsieve-2.3.2.post1 yfinance-0.2.11

# %%
# import the necessary libraries
import yfinance as yf
yf.pdr_override()
from pandas_datareader import data as pdr
import datetime
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import datetime as dt

# %%
#  import tensorflow libraries
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping


from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
import os 
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
#mount drive 
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# getting latest data
def get_data(stocks, start, end):
    df = pdr.get_data_yahoo(stocks, start, end)
    return df

endDate = datetime.datetime.now()
startDate = endDate - datetime.timedelta(days=30)

# %%
def lstm_split(data, n_steps): 
  X,y =[], []
  for i in range(len(data)-n_steps+1):
    X.append(data[i:i+n_steps, :-1])
    y.append(data[i+n_steps-1,-1])
  return np.array(X), np.array(y)

# %%
def plotGraph(y_test,y_pred,regressorName):
    if max(y_test) >= max(y_pred):
        my_range = int(max(y_test))
    else:
        my_range = int(max(y_pred))
    plt.figure(figsize=(15,10))
    plt.plot(range(len(y_test)), y_test, color='blue')
    plt.plot(range(len(y_pred)), y_pred, color='red')
    plt.legend()
    plt.title(regressorName)
    plt.show()
    return

# %%
# !pwd
# Out:
# /content

# %%
#!rm -r ./saved_model

# %%
tickers = ['TSLA', 'AAPL', 'AMZN', 'GOOG', 'MSFT']

# %%
def LSTM_model(X_train):
    
    model = Sequential()
    
    model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1],1)))
    model.add(Dropout(0.2))

    model.add(LSTM(units = 50, return_sequences = True))
    model.add(Dropout(0.2))

    model.add(LSTM(units = 50))
    model.add(Dropout(0.2))
    
    model.add(Dense(units=1))
    
    return model

# %%
# We try with another model to see if we get better predictions

for tick in tickers:
  prediction_days = 60
  scaler = MinMaxScaler(feature_range=(0,1))
  START_DATE = dt.datetime(2015,1,1)
  END_DATE = dt.datetime(2023,1,1)
  df = get_data(tick, START_DATE, END_DATE)
  scaled_data = scaler.fit_transform(df['Close'].values.reshape(-1,1))
  x_train = []
  y_train = []

  for x in range(prediction_days, len(scaled_data)):
      x_train.append(scaled_data[x - prediction_days:x, 0])
      y_train.append(scaled_data[x, 0])
  print(f"Data Preprocessing for {tick} Stocks")
  x_train, y_train = np.array(x_train), np.array(y_train)
  x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
  lstm = LSTM_model(x_train)
  lstm.summary()
  lstm.compile(optimizer='adam', 
                loss='mean_squared_error')
  checkpointer = ModelCheckpoint(filepath = tick+'_weights_best.hdf5', 
                               verbose = 2, 
                               save_best_only = True)

  lstm.fit(x_train, 
            y_train, 
            epochs=25, 
            batch_size = 32,
            callbacks = [checkpointer])
  END_DATE = dt.datetime(2023,1,1)

  START_DATE_TEST = END_DATE
  test_data = get_data(tick, START_DATE_TEST,dt.datetime.now())
  actual_prices = test_data['Close'].values

  total_dataset = pd.concat((df['Close'], test_data['Close']), axis=0)

  lstm_inputs = total_dataset[len(total_dataset) - len(test_data) - prediction_days:].values
  lstm_inputs = lstm_inputs.reshape(-1,1)
  lstm_inputs = scaler.transform(lstm_inputs)
  x_test = []
  for x in range(prediction_days, len(lstm_inputs)):
      x_test.append(lstm_inputs[x-prediction_days:x, 0])

  x_test = np.array(x_test)
  x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1] ,1))

  predicted_prices = lstm.predict(x_test)
  predicted_prices = scaler.inverse_transform(predicted_prices)
    # save model 
  directory = "lstm_saved_model"
  parent_dir = "/content"
  path = os.path.join(parent_dir, directory)
  os.makedirs(path, exist_ok=True) 
  print("Directory '% s' created" % directory) 

  lstm.save('lstm_saved_model/'+tick+'_model')
  plt.figure(figsize=(15,10))
  plt.plot(actual_prices, color='blue', label=f"Actual {tick} price")
  plt.plot(predicted_prices, color= 'green', label=f"Predicted {tick} price")
  plt.title(f"{tick} share price")
  plt.xlabel("time")
  plt.ylabel(f"{tick} share price")
  plt.legend()
  plt.show()
  # predicting next day
  real_data = [lstm_inputs[len(lstm_inputs)+1 - prediction_days:len(lstm_inputs+1),0]]
  real_data = np.array(real_data)
  real_data = np.reshape(real_data, (real_data.shape[0], real_data.shape[1], 1))
  prediction = lstm.predict(real_data)
  prediction = scaler.inverse_transform(prediction)
  print(f"prediction: {prediction}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data Preprocessing for TSLA Stocks
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  dropout (Dropout)           (None, 60, 50)            0
#
#  lstm_1 (LSTM)               (None, 60, 50)            20200
#
#  dropout_1 (Dropout)         (None, 60, 50)            0
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0105
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 26s 203ms/step - loss: 0.0105
# Epoch 2/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0019
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 5s 98ms/step - loss: 0.0019
# Epoch 3/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0019
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 136ms/step - loss: 0.0019
# Epoch 4/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0018
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 5s 101ms/step - loss: 0.0018
# Epoch 5/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0015
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 142ms/step - loss: 0.0015
# Epoch 6/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0013
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 103ms/step - loss: 0.0013
# Epoch 7/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0015
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 119ms/step - loss: 0.0015
# Epoch 8/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0015
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 118ms/step - loss: 0.0015
# Epoch 9/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0014
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 149ms/step - loss: 0.0014
# Epoch 10/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0011
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 120ms/step - loss: 0.0011
# Epoch 11/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0015
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 5s 100ms/step - loss: 0.0015
# Epoch 12/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0012
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 138ms/step - loss: 0.0012
# Epoch 13/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0012
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 5s 100ms/step - loss: 0.0012
# Epoch 14/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0010
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 137ms/step - loss: 0.0010
# Epoch 15/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0014
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 105ms/step - loss: 0.0014
# Epoch 16/25
# 54/54 [==============================] - ETA: 0s - loss: 9.8669e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 127ms/step - loss: 9.8669e-04
# Epoch 17/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0012
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 111ms/step - loss: 0.0012
# Epoch 18/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0012
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 105ms/step - loss: 0.0012
# Epoch 19/25
# 54/54 [==============================] - ETA: 0s - loss: 9.4892e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 135ms/step - loss: 9.4892e-04
# Epoch 20/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0011
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 104ms/step - loss: 0.0011
# Epoch 21/25
# 54/54 [==============================] - ETA: 0s - loss: 9.4915e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 143ms/step - loss: 9.4915e-04
# Epoch 22/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0013
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 107ms/step - loss: 0.0013
# Epoch 23/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0010
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 144ms/step - loss: 0.0010
# Epoch 24/25
# 54/54 [==============================] - ETA: 0s - loss: 9.2963e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 109ms/step - loss: 9.2963e-04
# Epoch 25/25
# 54/54 [==============================] - ETA: 0s - loss: 9.4004e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 146ms/step - loss: 9.4004e-04
# [*********************100%***********************]  1 of 1 completed
# 9/9 [==============================] - 2s 48ms/step
# Directory 'lstm_saved_model' created
# WARNING:absl:Found untraced functions such as _update_step_xla, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# 1/1 [==============================] - 1s 1s/step
# prediction: [[204.42845]]
# [*********************100%***********************]  1 of 1 completed
# Data Preprocessing for AAPL Stocks
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 60, 50)            10400
#
#  dropout_3 (Dropout)         (None, 60, 50)            0
#
#  lstm_4 (LSTM)               (None, 60, 50)            20200
#
#  dropout_4 (Dropout)         (None, 60, 50)            0
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dropout_5 (Dropout)         (None, 50)                0
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0140
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 14s 141ms/step - loss: 0.0140
# Epoch 2/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0020
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 104ms/step - loss: 0.0020
# Epoch 3/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0022
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 145ms/step - loss: 0.0022
# Epoch 4/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0019
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 107ms/step - loss: 0.0019
# Epoch 5/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0018
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 143ms/step - loss: 0.0018
# Epoch 6/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0018
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 108ms/step - loss: 0.0018
# Epoch 7/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0017
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 129ms/step - loss: 0.0017
# Epoch 8/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0018
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 117ms/step - loss: 0.0018
# Epoch 9/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0018
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 113ms/step - loss: 0.0018
# Epoch 10/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0016
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 136ms/step - loss: 0.0016
# Epoch 11/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0014
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 104ms/step - loss: 0.0014
# Epoch 12/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0013
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 146ms/step - loss: 0.0013
# Epoch 13/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0015
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 105ms/step - loss: 0.0015
# Epoch 14/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0014
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 143ms/step - loss: 0.0014
# Epoch 15/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0014
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0014
# Epoch 16/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0012
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 140ms/step - loss: 0.0012
# Epoch 17/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0011
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 110ms/step - loss: 0.0011
# Epoch 18/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0012
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 115ms/step - loss: 0.0012
# Epoch 19/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0014
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 127ms/step - loss: 0.0014
# Epoch 20/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0015
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 109ms/step - loss: 0.0015
# Epoch 21/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0013
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 144ms/step - loss: 0.0013
# Epoch 22/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0012
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 105ms/step - loss: 0.0012
# Epoch 23/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0010
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 142ms/step - loss: 0.0010
# Epoch 24/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0011
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 108ms/step - loss: 0.0011
# Epoch 25/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0010
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 142ms/step - loss: 0.0010
# [*********************100%***********************]  1 of 1 completed
# 9/9 [==============================] - 2s 31ms/step
# Directory 'lstm_saved_model' created
# WARNING:absl:Found untraced functions such as _update_step_xla, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# 1/1 [==============================] - 1s 1s/step
# prediction: [[151.56429]]
# [*********************100%***********************]  1 of 1 completed
# Data Preprocessing for AMZN Stocks
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 60, 50)            10400
#
#  dropout_6 (Dropout)         (None, 60, 50)            0
#
#  lstm_7 (LSTM)               (None, 60, 50)            20200
#
#  dropout_7 (Dropout)         (None, 60, 50)            0
#
#  lstm_8 (LSTM)               (None, 50)                20200
#
#  dropout_8 (Dropout)         (None, 50)                0
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0152
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 14s 109ms/step - loss: 0.0152
# Epoch 2/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0039
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 140ms/step - loss: 0.0039
# Epoch 3/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0033
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 111ms/step - loss: 0.0033
# Epoch 4/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0033
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 10s 181ms/step - loss: 0.0033
# Epoch 5/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0034
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 159ms/step - loss: 0.0034
# Epoch 6/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0035
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 161ms/step - loss: 0.0035
# Epoch 7/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0029
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 123ms/step - loss: 0.0029
# Epoch 8/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0028
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 156ms/step - loss: 0.0028
# Epoch 9/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0023
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 120ms/step - loss: 0.0023
# Epoch 10/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0026
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 156ms/step - loss: 0.0026
# Epoch 11/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0024
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 122ms/step - loss: 0.0024
# Epoch 12/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0022
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 157ms/step - loss: 0.0022
# Epoch 13/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0025
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 125ms/step - loss: 0.0025
# Epoch 14/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0022
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 163ms/step - loss: 0.0022
# Epoch 15/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0024
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 132ms/step - loss: 0.0024
# Epoch 16/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0022
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 160ms/step - loss: 0.0022
# Epoch 17/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0021
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 117ms/step - loss: 0.0021
# Epoch 18/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0022
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 156ms/step - loss: 0.0022
# Epoch 19/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0020
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 124ms/step - loss: 0.0020
# Epoch 20/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0018
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 158ms/step - loss: 0.0018
# Epoch 21/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0018
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 121ms/step - loss: 0.0018
# Epoch 22/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0015
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 156ms/step - loss: 0.0015
# Epoch 23/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0018
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 119ms/step - loss: 0.0018
# Epoch 24/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0017
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 154ms/step - loss: 0.0017
# Epoch 25/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0017
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 128ms/step - loss: 0.0017
# [*********************100%***********************]  1 of 1 completed
# 9/9 [==============================] - 3s 54ms/step
# Directory 'lstm_saved_model' created
# WARNING:absl:Found untraced functions such as _update_step_xla, lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses, lstm_cell_7_layer_call_fn, lstm_cell_7_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# 1/1 [==============================] - 3s 3s/step
# prediction: [[106.71296]]
# [*********************100%***********************]  1 of 1 completed
# Data Preprocessing for GOOG Stocks
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 60, 50)            10400
#
#  dropout_9 (Dropout)         (None, 60, 50)            0
#
#  lstm_10 (LSTM)              (None, 60, 50)            20200
#
#  dropout_10 (Dropout)        (None, 60, 50)            0
#
#  lstm_11 (LSTM)              (None, 50)                20200
#
#  dropout_11 (Dropout)        (None, 50)                0
#
#  dense_3 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0112
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 20s 160ms/step - loss: 0.0112
# Epoch 2/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0022
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0022
# Epoch 3/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0020
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 139ms/step - loss: 0.0020
# Epoch 4/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0022
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 172ms/step - loss: 0.0022
# Epoch 5/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0019
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 137ms/step - loss: 0.0019
# Epoch 6/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0021
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 10s 183ms/step - loss: 0.0021
# Epoch 7/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0021
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 152ms/step - loss: 0.0021
# Epoch 8/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0016
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 157ms/step - loss: 0.0016
# Epoch 9/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0015
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 163ms/step - loss: 0.0015
# Epoch 10/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0014
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 140ms/step - loss: 0.0014
# Epoch 11/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0013
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0013
# Epoch 12/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0016
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 140ms/step - loss: 0.0016
# Epoch 13/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0014
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0014
# Epoch 14/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0014
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 150ms/step - loss: 0.0014
# Epoch 15/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0015
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 168ms/step - loss: 0.0015
# Epoch 16/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0012
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 169ms/step - loss: 0.0012
# Epoch 17/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0012
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 142ms/step - loss: 0.0012
# Epoch 18/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0012
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0012
# Epoch 19/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0013
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 144ms/step - loss: 0.0013
# Epoch 20/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0011
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 174ms/step - loss: 0.0011
# Epoch 21/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0011
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 159ms/step - loss: 0.0011
# Epoch 22/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0013
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 146ms/step - loss: 0.0013
# Epoch 23/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0010
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0010
# Epoch 24/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0012
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 130ms/step - loss: 0.0012
# Epoch 25/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0011
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 10s 180ms/step - loss: 0.0011
# [*********************100%***********************]  1 of 1 completed
# 9/9 [==============================] - 2s 39ms/step
# Directory 'lstm_saved_model' created
# WARNING:absl:Found untraced functions such as _update_step_xla, lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses, lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# 1/1 [==============================] - 2s 2s/step
# prediction: [[101.55009]]
# [*********************100%***********************]  1 of 1 completed
# Data Preprocessing for MSFT Stocks
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 60, 50)            10400
#
#  dropout_12 (Dropout)        (None, 60, 50)            0
#
#  lstm_13 (LSTM)              (None, 60, 50)            20200
#
#  dropout_13 (Dropout)        (None, 60, 50)            0
#
#  lstm_14 (LSTM)              (None, 50)                20200
#
#  dropout_14 (Dropout)        (None, 50)                0
#
#  dense_4 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0149
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 15s 156ms/step - loss: 0.0149
# Epoch 2/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0022
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 114ms/step - loss: 0.0022
# Epoch 3/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0020
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 155ms/step - loss: 0.0020
# Epoch 4/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0019
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 114ms/step - loss: 0.0019
# Epoch 5/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0023
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 151ms/step - loss: 0.0023
# Epoch 6/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0016
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 115ms/step - loss: 0.0016
# Epoch 7/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0017
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 150ms/step - loss: 0.0017
# Epoch 8/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0017
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 112ms/step - loss: 0.0017
# Epoch 9/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0013
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 9s 158ms/step - loss: 0.0013
# Epoch 10/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0014
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 116ms/step - loss: 0.0014
# Epoch 11/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0017
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 153ms/step - loss: 0.0017
# Epoch 12/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0014
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 116ms/step - loss: 0.0014
# Epoch 13/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0012
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 149ms/step - loss: 0.0012
# Epoch 14/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0013
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 6s 118ms/step - loss: 0.0013
# Epoch 15/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0013
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 150ms/step - loss: 0.0013
# Epoch 16/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0013
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 127ms/step - loss: 0.0013
# Epoch 17/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0014
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 142ms/step - loss: 0.0014
# Epoch 18/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0017
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 128ms/step - loss: 0.0017
# Epoch 19/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0011
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 142ms/step - loss: 0.0011
# Epoch 20/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0012
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 127ms/step - loss: 0.0012
# Epoch 21/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0014
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 149ms/step - loss: 0.0014
# Epoch 22/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0012
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 128ms/step - loss: 0.0012
# Epoch 23/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0013
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 136ms/step - loss: 0.0013
# Epoch 24/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0015
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 7s 133ms/step - loss: 0.0015
# Epoch 25/25
# 54/54 [==============================] - ETA: 0s - loss: 0.0011
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 54/54 [==============================] - 8s 142ms/step - loss: 0.0011
# [*********************100%***********************]  1 of 1 completed
# 9/9 [==============================] - 2s 34ms/step
# Directory 'lstm_saved_model' created
# WARNING:absl:Found untraced functions such as _update_step_xla, lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# 1/1 [==============================] - 2s 2s/step
# prediction: [[264.40982]]

# %%
# !zip -r lstm_saved_model.zip lstm_saved_model/
# Out:
#   adding: lstm_saved_model/ (stored 0%)
#   adding: lstm_saved_model/MSFT_model/ (stored 0%)
#   adding: lstm_saved_model/MSFT_model/keras_metadata.pb (deflated 92%)
#   adding: lstm_saved_model/MSFT_model/variables/ (stored 0%)
#   adding: lstm_saved_model/MSFT_model/variables/variables.index (deflated 64%)
#   adding: lstm_saved_model/MSFT_model/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: lstm_saved_model/MSFT_model/assets/ (stored 0%)
#   adding: lstm_saved_model/MSFT_model/fingerprint.pb (stored 0%)
#   adding: lstm_saved_model/MSFT_model/saved_model.pb (deflated 90%)
#   adding: lstm_saved_model/TSLA_model/ (stored 0%)
#   adding: lstm_saved_model/TSLA_model/keras_metadata.pb (deflated 92%)
#   adding: lstm_saved_model/TSLA_model/variables/ (stored 0%)
#   adding: lstm_saved_model/TSLA_model/variables/variables.index (deflated 64%)
#   adding: lstm_saved_model/TSLA_model/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: lstm_saved_model/TSLA_model/assets/ (stored 0%)
#   adding: lstm_saved_model/TSLA_model/fingerprint.pb (stored 0%)
#   adding: lstm_saved_model/TSLA_model/saved_model.pb (deflated 91%)
#   adding: lstm_saved_model/AAPL_model/ (stored 0%)
#   adding: lstm_saved_model/AAPL_model/keras_metadata.pb (deflated 92%)
#   adding: lstm_saved_model/AAPL_model/variables/ (stored 0%)
#   adding: lstm_saved_model/AAPL_model/variables/variables.index (deflated 64%)
#   adding: lstm_saved_model/AAPL_model/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: lstm_saved_model/AAPL_model/assets/ (stored 0%)
#   adding: lstm_saved_model/AAPL_model/fingerprint.pb (stored 0%)
#   adding: lstm_saved_model/AAPL_model/saved_model.pb (deflated 91%)
#   adding: lstm_saved_model/GOOG_model/ (stored 0%)
#   adding: lstm_saved_model/GOOG_model/keras_metadata.pb (deflated 92%)
#   adding: lstm_saved_model/GOOG_model/variables/ (stored 0%)
#   adding: lstm_saved_model/GOOG_model/variables/variables.index (deflated 64%)
#   adding: lstm_saved_model/GOOG_model/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: lstm_saved_model/GOOG_model/assets/ (stored 0%)
#   adding: lstm_saved_model/GOOG_model/fingerprint.pb (stored 0%)
#   adding: lstm_saved_model/GOOG_model/saved_model.pb (deflated 92%)
#   adding: lstm_saved_model/AMZN_model/ (stored 0%)
#   adding: lstm_saved_model/AMZN_model/keras_metadata.pb (deflated 92%)
#   adding: lstm_saved_model/AMZN_model/variables/ (stored 0%)
#   adding: lstm_saved_model/AMZN_model/variables/variables.index (deflated 64%)
#   adding: lstm_saved_model/AMZN_model/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: lstm_saved_model/AMZN_model/assets/ (stored 0%)
#   adding: lstm_saved_model/AMZN_model/fingerprint.pb (stored 0%)
#   adding: lstm_saved_model/AMZN_model/saved_model.pb (deflated 91%)

# %%
from google.colab import files
files.download("/content/lstm_saved_model.zip")

# %% [markdown]
# # Second Method using LSTM
# This method is less precise so we chose the previous method

# %%
from numpy.core.fromnumeric import mean
for tick in tickers: 
  startDate = dt.datetime(2015,1,1)
  endDate = dt.datetime(2023,1,1)
  df = get_data(tick, startDate, endDate)
  print(f"Analysing Data for {tick} Stocks")
  print(df.head())
  print(f"Plotting Data for {tick} Stocks")
  plt.figure(figsize=(15,10))
  plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
  plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=60))
  x_dates = [d for d in df.index.values]

  plt.plot(x_dates, df['High'], label='High')
  plt.plot(x_dates, df['Low'], label='Low')
  plt.xlabel('Time Scale')
  plt.ylabel('Scaled USD')
  plt.legend()
  plt.gcf().autofmt_xdate()
  plt.show()
  print(f"Data Preprocessing for {tick} Stocks")
  target_y = df['Close']
  X_feat = df.iloc[:,0:3]
  print("Feature Scaling for ", tick)
  sc = StandardScaler()
  X_ft = sc.fit_transform(X_feat.values)
  X_ft = pd.DataFrame(columns = X_feat.columns, data=X_ft, index=X_feat.index)
  print("Train and Test Sets for Stock Price ", tick)
  X1, y1 = lstm_split(df.values, n_steps=2)
  train_split = 0.8
  split_idx = int(np.ceil(len(X1)*train_split))
  date_index = df.index

  X_train, X_test = X1[:split_idx], X1[split_idx:]
  y_train, y_test = y1[:split_idx], y1[split_idx:]
  X_train_date, X_test_date = date_index[:split_idx], date_index[split_idx:]

  print(X1.shape, X_train.shape, X_test.shape, y_test.shape)
  lstm = Sequential()
  lstm.add(LSTM(50, input_shape =(X_train.shape[1], X_train.shape[2]),
                activation='relu', return_sequences=True))
  lstm.add(LSTM(50, activation='relu'))
  lstm.add(Dense(1))
  lstm.compile(loss='mean_squared_error', optimizer='adam')
  lstm.summary()
  print("Reshape training array to 2d")

  history=lstm.fit(X_train, y_train, epochs=100, batch_size=4, verbose=2, shuffle=False)
  y_pred = lstm.predict(X_test)
  # save model 
  directory = "saved_model"
  parent_dir = "/content"
  path = os.path.join(parent_dir, directory)
  os.makedirs(path, exist_ok=True) 
  print("Directory '% s' created" % directory) 

  lstm.save('saved_model/'+tick+'_model')
  print("Y_pred.shape",y_pred.shape)
  print("Y_test.shape", y_test.shape)
  y_pred_1 = y_pred.reshape(-1)

  # print("Reshaped y_pred is", y_pred_1.shape)
  # y_pred_1d = y_pred_1[:4]
  # print("Reshaped y_pred is",y_pred_1d.shape)
  rmse = mean_squared_error(y_test, y_pred_1, squared=False)
  mape = mean_absolute_percentage_error(y_test, y_pred_1)
  print("RSME: ", rmse)
  print("MAPE: ", mape)

  print("Plot Prediction for %s Stock", tick)
  # plot y_test with y_pred
  plotGraph(y_test, y_pred, "LSTM")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Analysing Data for TSLA Stocks
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-01-02  14.858000  14.883333  14.217333  14.620667  14.620667  71466000
# 2015-01-05  14.303333  14.433333  13.810667  14.006000  14.006000  80527500
# 2015-01-06  14.004000  14.280000  13.614000  14.085333  14.085333  93928500
# 2015-01-07  14.223333  14.318667  13.985333  14.063333  14.063333  44526000
# 2015-01-08  14.187333  14.253333  14.000667  14.041333  14.041333  51637500
# Plotting Data for TSLA Stocks
# Data Preprocessing for TSLA Stocks
# Feature Scaling for  TSLA
# Train and Test Sets for Stock Price  TSLA
# (2013, 2, 5) (1611, 2, 5) (402, 2, 5) (402,)
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_19 (LSTM)              (None, 2, 50)             11200
#
#  lstm_20 (LSTM)              (None, 50)                20200
#
#  dense_7 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 31,451
# Trainable params: 31,451
# Non-trainable params: 0
# _________________________________________________________________
# Reshape training array to 2d
# Epoch 1/100
# 403/403 - 5s - loss: 20943637072314368.0000 - 5s/epoch - 13ms/step
# Epoch 2/100
# 403/403 - 2s - loss: 18671129073811456.0000 - 2s/epoch - 5ms/step
# Epoch 3/100
# 403/403 - 2s - loss: 16918581627322368.0000 - 2s/epoch - 5ms/step
# Epoch 4/100
# 403/403 - 2s - loss: 16188555298603008.0000 - 2s/epoch - 5ms/step
# Epoch 5/100
# 403/403 - 3s - loss: 16038860655951872.0000 - 3s/epoch - 7ms/step
# Epoch 6/100
# 403/403 - 2s - loss: 15979471995666432.0000 - 2s/epoch - 6ms/step
# Epoch 7/100
# 403/403 - 2s - loss: 15948083300925440.0000 - 2s/epoch - 5ms/step
# Epoch 8/100
# 403/403 - 2s - loss: 15928550863405056.0000 - 2s/epoch - 5ms/step
# Epoch 9/100
# 403/403 - 2s - loss: 15914935817076736.0000 - 2s/epoch - 5ms/step
# Epoch 10/100
# 403/403 - 2s - loss: 15904577429700608.0000 - 2s/epoch - 5ms/step
# Epoch 11/100
# 403/403 - 3s - loss: 15896124934062080.0000 - 3s/epoch - 8ms/step
# Epoch 12/100
# 403/403 - 2s - loss: 15888796646113280.0000 - 2s/epoch - 6ms/step
# Epoch 13/100
# 403/403 - 2s - loss: 15882195281379328.0000 - 2s/epoch - 5ms/step
# Epoch 14/100
# 403/403 - 2s - loss: 15876025560858624.0000 - 2s/epoch - 5ms/step
# Epoch 15/100
# 403/403 - 2s - loss: 15870124275793920.0000 - 2s/epoch - 5ms/step
# Epoch 16/100
# 403/403 - 2s - loss: 15864391568195584.0000 - 2s/epoch - 5ms/step
# Epoch 17/100
# 403/403 - 3s - loss: 15858760866070528.0000 - 3s/epoch - 6ms/step
# Epoch 18/100
# 403/403 - 3s - loss: 15853190293487616.0000 - 3s/epoch - 7ms/step
# Epoch 19/100
# 403/403 - 2s - loss: 15847649785675776.0000 - 2s/epoch - 5ms/step
# Epoch 20/100
# 403/403 - 2s - loss: 15842125383991296.0000 - 2s/epoch - 5ms/step
# Epoch 21/100
# 403/403 - 2s - loss: 15836602056048640.0000 - 2s/epoch - 5ms/step
# Epoch 22/100
# 403/403 - 2s - loss: 15831074433138688.0000 - 2s/epoch - 5ms/step
# Epoch 23/100
# 403/403 - 2s - loss: 15825533925326848.0000 - 2s/epoch - 5ms/step
# Epoch 24/100
# 403/403 - 3s - loss: 15819990196289536.0000 - 3s/epoch - 8ms/step
# Epoch 25/100
# 403/403 - 2s - loss: 15814414254997504.0000 - 2s/epoch - 5ms/step
# Epoch 26/100
# 403/403 - 2s - loss: 15808825428803584.0000 - 2s/epoch - 5ms/step
# Epoch 27/100
# 403/403 - 2s - loss: 15803226938933248.0000 - 2s/epoch - 5ms/step
# Epoch 28/100
# 403/403 - 2s - loss: 15797593015582720.0000 - 2s/epoch - 5ms/step
# Epoch 29/100
# 403/403 - 2s - loss: 15791944059846656.0000 - 2s/epoch - 5ms/step
# Epoch 30/100
# 403/403 - 3s - loss: 15786271481790464.0000 - 3s/epoch - 7ms/step
# Epoch 31/100
# 403/403 - 3s - loss: 15780572060188672.0000 - 3s/epoch - 7ms/step
# Epoch 32/100
# 403/403 - 2s - loss: 15774855458717696.0000 - 2s/epoch - 5ms/step
# Epoch 33/100
# 403/403 - 2s - loss: 15769104497508352.0000 - 2s/epoch - 5ms/step
# Epoch 34/100
# 403/403 - 2s - loss: 15763333135204352.0000 - 2s/epoch - 4ms/step
# Epoch 35/100
# 403/403 - 2s - loss: 15757530634387456.0000 - 2s/epoch - 5ms/step
# Epoch 36/100
# 403/403 - 2s - loss: 15751688405123072.0000 - 2s/epoch - 6ms/step
# Epoch 37/100
# 403/403 - 3s - loss: 15745835438440448.0000 - 3s/epoch - 7ms/step
# Epoch 38/100
# 403/403 - 2s - loss: 15739938448343040.0000 - 2s/epoch - 6ms/step
# Epoch 39/100
# 403/403 - 2s - loss: 15734012467216384.0000 - 2s/epoch - 5ms/step
# Epoch 40/100
# 403/403 - 2s - loss: 15728052126351360.0000 - 2s/epoch - 5ms/step
# Epoch 41/100
# 403/403 - 2s - loss: 15722061720715264.0000 - 2s/epoch - 5ms/step
# Epoch 42/100
# 403/403 - 2s - loss: 15716031586631680.0000 - 2s/epoch - 5ms/step
# Epoch 43/100
# 403/403 - 3s - loss: 15709962797842432.0000 - 3s/epoch - 7ms/step
# Epoch 44/100
# 403/403 - 3s - loss: 15703849985638400.0000 - 3s/epoch - 7ms/step
# Epoch 45/100
# 403/403 - 2s - loss: 15697719993565184.0000 - 2s/epoch - 5ms/step
# Epoch 46/100
# 403/403 - 2s - loss: 15691530945691648.0000 - 2s/epoch - 5ms/step
# Epoch 47/100
# 403/403 - 2s - loss: 15685294653177856.0000 - 2s/epoch - 5ms/step
# Epoch 48/100
# 403/403 - 2s - loss: 15679029369634816.0000 - 2s/epoch - 5ms/step
# Epoch 49/100
# 403/403 - 2s - loss: 15672721136418816.0000 - 2s/epoch - 5ms/step
# Epoch 50/100
# 403/403 - 3s - loss: 15666365658562560.0000 - 3s/epoch - 7ms/step
# Epoch 51/100
# 403/403 - 2s - loss: 15659958641098752.0000 - 2s/epoch - 5ms/step
# Epoch 52/100
# 403/403 - 2s - loss: 15653509747703808.0000 - 2s/epoch - 5ms/step
# Epoch 53/100
# 403/403 - 2s - loss: 15647014683410432.0000 - 2s/epoch - 5ms/step
# Epoch 54/100
# 403/403 - 2s - loss: 15640458415833088.0000 - 2s/epoch - 5ms/step
# Epoch 55/100
# 403/403 - 2s - loss: 15633847387422720.0000 - 2s/epoch - 5ms/step
# Epoch 56/100
# 403/403 - 3s - loss: 15627181598179328.0000 - 3s/epoch - 7ms/step
# Epoch 57/100
# 403/403 - 2s - loss: 15620471785521152.0000 - 2s/epoch - 6ms/step
# Epoch 58/100
# 403/403 - 2s - loss: 15613694327128064.0000 - 2s/epoch - 5ms/step
# Epoch 59/100
# 403/403 - 2s - loss: 15606867476611072.0000 - 2s/epoch - 5ms/step
# Epoch 60/100
# 403/403 - 2s - loss: 15599975127842816.0000 - 2s/epoch - 5ms/step
# Epoch 61/100
# 403/403 - 2s - loss: 15593021575790592.0000 - 2s/epoch - 5ms/step
# Epoch 62/100
# 403/403 - 2s - loss: 15586001451745280.0000 - 2s/epoch - 6ms/step
# Epoch 63/100
# 403/403 - 3s - loss: 15578911534481408.0000 - 3s/epoch - 7ms/step
# Epoch 64/100
# 403/403 - 2s - loss: 15571758266449920.0000 - 2s/epoch - 5ms/step
# Epoch 65/100
# 403/403 - 2s - loss: 15564530910232576.0000 - 2s/epoch - 5ms/step
# Epoch 66/100
# 403/403 - 2s - loss: 15557244498214912.0000 - 2s/epoch - 5ms/step
# Epoch 67/100
# 403/403 - 2s - loss: 15549876481818624.0000 - 2s/epoch - 5ms/step
# Epoch 68/100
# 403/403 - 2s - loss: 15542425787301888.0000 - 2s/epoch - 5ms/step
# Epoch 69/100
# 403/403 - 3s - loss: 15534908520792064.0000 - 3s/epoch - 7ms/step
# Epoch 70/100
# 403/403 - 2s - loss: 15527306428678144.0000 - 2s/epoch - 6ms/step
# Epoch 71/100
# 403/403 - 2s - loss: 15519619510960128.0000 - 2s/epoch - 5ms/step
# Epoch 72/100
# 403/403 - 2s - loss: 15511840251445248.0000 - 2s/epoch - 5ms/step
# Epoch 73/100
# 403/403 - 2s - loss: 15503978313809920.0000 - 2s/epoch - 5ms/step
# Epoch 74/100
# 403/403 - 2s - loss: 15496025108119552.0000 - 2s/epoch - 5ms/step
# Epoch 75/100
# 403/403 - 3s - loss: 15487980634374144.0000 - 3s/epoch - 6ms/step
# Epoch 76/100
# 403/403 - 3s - loss: 15479844892573696.0000 - 3s/epoch - 7ms/step
# Epoch 77/100
# 403/403 - 2s - loss: 15471597481623552.0000 - 2s/epoch - 5ms/step
# Epoch 78/100
# 403/403 - 2s - loss: 15463253433909248.0000 - 2s/epoch - 5ms/step
# Epoch 79/100
# 403/403 - 2s - loss: 15454804159496192.0000 - 2s/epoch - 5ms/step
# Epoch 80/100
# 403/403 - 2s - loss: 15446242142191616.0000 - 2s/epoch - 5ms/step
# Epoch 81/100
# 403/403 - 2s - loss: 15437577045671936.0000 - 2s/epoch - 6ms/step
# Epoch 82/100
# 403/403 - 3s - loss: 15428800280002560.0000 - 3s/epoch - 7ms/step
# Epoch 83/100
# 403/403 - 2s - loss: 15419893591572480.0000 - 2s/epoch - 5ms/step
# Epoch 84/100
# 403/403 - 2s - loss: 15410868791541760.0000 - 2s/epoch - 5ms/step
# Epoch 85/100
# 403/403 - 2s - loss: 15401720511201280.0000 - 2s/epoch - 5ms/step
# Epoch 86/100
# 403/403 - 2s - loss: 15392443381841920.0000 - 2s/epoch - 5ms/step
# Epoch 87/100
# 403/403 - 2s - loss: 15383024518561792.0000 - 2s/epoch - 5ms/step
# Epoch 88/100
# 403/403 - 3s - loss: 15373468216328192.0000 - 3s/epoch - 7ms/step
# Epoch 89/100
# 403/403 - 3s - loss: 15363765885206528.0000 - 3s/epoch - 8ms/step
# Epoch 90/100
# 403/403 - 3s - loss: 15353916451454976.0000 - 3s/epoch - 7ms/step
# Epoch 91/100
# 403/403 - 2s - loss: 15343924210040832.0000 - 2s/epoch - 5ms/step
# Epoch 92/100
# 403/403 - 2s - loss: 15333764464902144.0000 - 2s/epoch - 5ms/step
# Epoch 93/100
# 403/403 - 2s - loss: 15323449027198976.0000 - 2s/epoch - 5ms/step
# Epoch 94/100
# 403/403 - 2s - loss: 15312955348353024.0000 - 2s/epoch - 5ms/step
# Epoch 95/100
# 403/403 - 3s - loss: 15302292018298880.0000 - 3s/epoch - 8ms/step
# Epoch 96/100
# 403/403 - 2s - loss: 15291442930909184.0000 - 2s/epoch - 6ms/step
# Epoch 97/100
# 403/403 - 2s - loss: 15280412381151232.0000 - 2s/epoch - 5ms/step
# Epoch 98/100
# 403/403 - 2s - loss: 15269188557864960.0000 - 2s/epoch - 5ms/step
# Epoch 99/100
# 403/403 - 2s - loss: 15257768239824896.0000 - 2s/epoch - 4ms/step
# Epoch 100/100
# 403/403 - 2s - loss: 15246135320903680.0000 - 2s/epoch - 5ms/step
# 13/13 [==============================] - 0s 3ms/step
# Directory 'saved_model' created
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Y_pred.shape (402, 1)
# Y_test.shape (402,)
# RSME:  183036205.5851171
# MAPE:  2.5552610966916975
# Plot Prediction for %s Stock TSLA
# [*********************100%***********************]  1 of 1 completed
# Analysing Data for AAPL Stocks
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2015-01-02  27.847500  27.860001  26.837500  27.332500  24.565697  212818400
# 2015-01-05  27.072500  27.162500  26.352501  26.562500  23.873644  257142000
# 2015-01-06  26.635000  26.857500  26.157499  26.565001  23.875889  263188400
# 2015-01-07  26.799999  27.049999  26.674999  26.937500  24.210684  160423600
# 2015-01-08  27.307501  28.037500  27.174999  27.972500  25.140915  237458000
# Plotting Data for AAPL Stocks
# Data Preprocessing for AAPL Stocks
# Feature Scaling for  AAPL
# Train and Test Sets for Stock Price  AAPL
# (2013, 2, 5) (1611, 2, 5) (402, 2, 5) (402,)
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_21 (LSTM)              (None, 2, 50)             11200
#
#  lstm_22 (LSTM)              (None, 50)                20200
#
#  dense_8 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 31,451
# Trainable params: 31,451
# Non-trainable params: 0
# _________________________________________________________________
# Reshape training array to 2d
# Epoch 1/100
# 403/403 - 6s - loss: 24943456363216896.0000 - 6s/epoch - 14ms/step
# Epoch 2/100
# 403/403 - 2s - loss: 19733729752645632.0000 - 2s/epoch - 5ms/step
# Epoch 3/100
# 403/403 - 3s - loss: 13276634043908096.0000 - 3s/epoch - 7ms/step
# Epoch 4/100
# 403/403 - 3s - loss: 12271983211315200.0000 - 3s/epoch - 7ms/step
# Epoch 5/100
# 403/403 - 2s - loss: 12115137448116224.0000 - 2s/epoch - 5ms/step
# Epoch 6/100
# 403/403 - 2s - loss: 12057927409991680.0000 - 2s/epoch - 5ms/step
# Epoch 7/100
# 403/403 - 2s - loss: 12028999731511296.0000 - 2s/epoch - 5ms/step
# Epoch 8/100
# 403/403 - 2s - loss: 12011500961005568.0000 - 2s/epoch - 5ms/step
# Epoch 9/100
# 403/403 - 2s - loss: 11999611417788416.0000 - 2s/epoch - 5ms/step
# Epoch 10/100
# 403/403 - 3s - loss: 11990782038769664.0000 - 3s/epoch - 8ms/step
# Epoch 11/100
# 403/403 - 2s - loss: 11983814528073728.0000 - 2s/epoch - 5ms/step
# Epoch 12/100
# 403/403 - 2s - loss: 11977984109969408.0000 - 2s/epoch - 5ms/step
# Epoch 13/100
# 403/403 - 2s - loss: 11972911753592832.0000 - 2s/epoch - 5ms/step
# Epoch 14/100
# 403/403 - 2s - loss: 11968325802262528.0000 - 2s/epoch - 5ms/step
# Epoch 15/100
# 403/403 - 2s - loss: 11964088817025024.0000 - 2s/epoch - 5ms/step
# Epoch 16/100
# 403/403 - 3s - loss: 11960069801377792.0000 - 3s/epoch - 7ms/step
# Epoch 17/100
# 403/403 - 2s - loss: 11956198962102272.0000 - 2s/epoch - 6ms/step
# Epoch 18/100
# 403/403 - 2s - loss: 11952446234427392.0000 - 2s/epoch - 5ms/step
# Epoch 19/100
# 403/403 - 2s - loss: 11948772963647488.0000 - 2s/epoch - 5ms/step
# Epoch 20/100
# 403/403 - 2s - loss: 11945138347573248.0000 - 2s/epoch - 5ms/step
# Epoch 21/100
# 403/403 - 2s - loss: 11941541312462848.0000 - 2s/epoch - 5ms/step
# Epoch 22/100
# 403/403 - 3s - loss: 11937964678447104.0000 - 3s/epoch - 6ms/step
# Epoch 23/100
# 403/403 - 3s - loss: 11934396634365952.0000 - 3s/epoch - 7ms/step
# Epoch 24/100
# 403/403 - 2s - loss: 11930842548928512.0000 - 2s/epoch - 5ms/step
# Epoch 25/100
# 403/403 - 2s - loss: 11927287389749248.0000 - 2s/epoch - 5ms/step
# Epoch 26/100
# 403/403 - 2s - loss: 11923733304311808.0000 - 2s/epoch - 5ms/step
# Epoch 27/100
# 403/403 - 2s - loss: 11920177071390720.0000 - 2s/epoch - 5ms/step
# Epoch 28/100
# 403/403 - 2s - loss: 11916628354662400.0000 - 2s/epoch - 6ms/step
# Epoch 29/100
# 403/403 - 3s - loss: 11913066753032192.0000 - 3s/epoch - 8ms/step
# Epoch 30/100
# 403/403 - 2s - loss: 11909504077660160.0000 - 2s/epoch - 5ms/step
# Epoch 31/100
# 403/403 - 2s - loss: 11905929591128064.0000 - 2s/epoch - 5ms/step
# Epoch 32/100
# 403/403 - 2s - loss: 11902358325821440.0000 - 2s/epoch - 5ms/step
# Epoch 33/100
# 403/403 - 2s - loss: 11898768806903808.0000 - 2s/epoch - 5ms/step
# Epoch 34/100
# 403/403 - 2s - loss: 11895179287986176.0000 - 2s/epoch - 5ms/step
# Epoch 35/100
# 403/403 - 3s - loss: 11891579031650304.0000 - 3s/epoch - 7ms/step
# Epoch 36/100
# 403/403 - 2s - loss: 11887974480347136.0000 - 2s/epoch - 6ms/step
# Epoch 37/100
# 403/403 - 2s - loss: 11884353822916608.0000 - 2s/epoch - 5ms/step
# Epoch 38/100
# 403/403 - 2s - loss: 11880735312969728.0000 - 2s/epoch - 5ms/step
# Epoch 39/100
# 403/403 - 2s - loss: 11877101770637312.0000 - 2s/epoch - 5ms/step
# Epoch 40/100
# 403/403 - 2s - loss: 11873454269661184.0000 - 2s/epoch - 5ms/step
# Epoch 41/100
# 403/403 - 3s - loss: 11869802473717760.0000 - 3s/epoch - 6ms/step
# Epoch 42/100
# 403/403 - 3s - loss: 11866146382807040.0000 - 3s/epoch - 7ms/step
# Epoch 43/100
# 403/403 - 2s - loss: 11862473112027136.0000 - 2s/epoch - 5ms/step
# Epoch 44/100
# 403/403 - 2s - loss: 11858797693763584.0000 - 2s/epoch - 5ms/step
# Epoch 45/100
# 403/403 - 2s - loss: 11855100800663552.0000 - 2s/epoch - 5ms/step
# Epoch 46/100
# 403/403 - 2s - loss: 11851398538854400.0000 - 2s/epoch - 5ms/step
# Epoch 47/100
# 403/403 - 2s - loss: 11847681244659712.0000 - 2s/epoch - 6ms/step
# Epoch 48/100
# 403/403 - 3s - loss: 11843949991821312.0000 - 3s/epoch - 7ms/step
# Epoch 49/100
# 403/403 - 2s - loss: 11840212296531968.0000 - 2s/epoch - 5ms/step
# Epoch 50/100
# 403/403 - 2s - loss: 11836457421373440.0000 - 2s/epoch - 5ms/step
# Epoch 51/100
# 403/403 - 2s - loss: 11832684292603904.0000 - 2s/epoch - 5ms/step
# Epoch 52/100
# 403/403 - 2s - loss: 11828910090092544.0000 - 2s/epoch - 5ms/step
# Epoch 53/100
# 403/403 - 2s - loss: 11825125150162944.0000 - 2s/epoch - 5ms/step
# Epoch 54/100
# 403/403 - 3s - loss: 11821326251589632.0000 - 3s/epoch - 8ms/step
# Epoch 55/100
# 403/403 - 2s - loss: 11817510173147136.0000 - 2s/epoch - 5ms/step
# Epoch 56/100
# 403/403 - 2s - loss: 11813667251159040.0000 - 2s/epoch - 5ms/step
# Epoch 57/100
# 403/403 - 2s - loss: 11809821107945472.0000 - 2s/epoch - 5ms/step
# Epoch 58/100
# 403/403 - 2s - loss: 11805955637379072.0000 - 2s/epoch - 5ms/step
# Epoch 59/100
# 403/403 - 2s - loss: 11802077281910784.0000 - 2s/epoch - 5ms/step
# Epoch 60/100
# 403/403 - 3s - loss: 11798180672831488.0000 - 3s/epoch - 7ms/step
# Epoch 61/100
# 403/403 - 3s - loss: 11794269031366656.0000 - 3s/epoch - 7ms/step
# Epoch 62/100
# 403/403 - 2s - loss: 11790343431258112.0000 - 2s/epoch - 5ms/step
# Epoch 63/100
# 403/403 - 2s - loss: 11786403872505856.0000 - 2s/epoch - 5ms/step
# Epoch 64/100
# 403/403 - 2s - loss: 11782441765175296.0000 - 2s/epoch - 5ms/step
# Epoch 65/100
# 403/403 - 2s - loss: 11778452814299136.0000 - 2s/epoch - 5ms/step
# Epoch 66/100
# 403/403 - 2s - loss: 11774459568455680.0000 - 2s/epoch - 6ms/step
# Epoch 67/100
# 403/403 - 3s - loss: 11770439479066624.0000 - 3s/epoch - 7ms/step
# Epoch 68/100
# 403/403 - 2s - loss: 11766409726001152.0000 - 2s/epoch - 5ms/step
# Epoch 69/100
# 403/403 - 2s - loss: 11762353129390080.0000 - 2s/epoch - 5ms/step
# Epoch 70/100
# 403/403 - 2s - loss: 11758277205426176.0000 - 2s/epoch - 5ms/step
# Epoch 71/100
# 403/403 - 2s - loss: 11754178732883968.0000 - 2s/epoch - 5ms/step
# Epoch 72/100
# 403/403 - 2s - loss: 11750055564279808.0000 - 2s/epoch - 6ms/step
# Epoch 73/100
# 403/403 - 3s - loss: 11745917363290112.0000 - 3s/epoch - 8ms/step
# Epoch 74/100
# 403/403 - 2s - loss: 11741761982431232.0000 - 2s/epoch - 5ms/step
# Epoch 75/100
# 403/403 - 2s - loss: 11737577610543104.0000 - 2s/epoch - 5ms/step
# Epoch 76/100
# 403/403 - 2s - loss: 11733372837560320.0000 - 2s/epoch - 5ms/step
# Epoch 77/100
# 403/403 - 2s - loss: 11729146589741056.0000 - 2s/epoch - 5ms/step
# Epoch 78/100
# 403/403 - 2s - loss: 11724893498376192.0000 - 2s/epoch - 5ms/step
# Epoch 79/100
# 403/403 - 3s - loss: 11720621079658496.0000 - 3s/epoch - 8ms/step
# Epoch 80/100
# 403/403 - 2s - loss: 11716320743653376.0000 - 2s/epoch - 6ms/step
# Epoch 81/100
# 403/403 - 2s - loss: 11711993564102656.0000 - 2s/epoch - 5ms/step
# Epoch 82/100
# 403/403 - 2s - loss: 11707644909715456.0000 - 2s/epoch - 5ms/step
# Epoch 83/100
# 403/403 - 2s - loss: 11703258674364416.0000 - 2s/epoch - 5ms/step
# Epoch 84/100
# 403/403 - 2s - loss: 11698848816693248.0000 - 2s/epoch - 5ms/step
# Epoch 85/100
# 403/403 - 3s - loss: 11694415336701952.0000 - 3s/epoch - 7ms/step
# Epoch 86/100
# 403/403 - 3s - loss: 11689961455616000.0000 - 3s/epoch - 6ms/step
# Epoch 87/100
# 403/403 - 2s - loss: 11685462477373440.0000 - 2s/epoch - 5ms/step
# Epoch 88/100
# 403/403 - 2s - loss: 11680954909196288.0000 - 2s/epoch - 5ms/step
# Epoch 89/100
# 403/403 - 2s - loss: 11676401170120704.0000 - 2s/epoch - 5ms/step
# Epoch 90/100
# 403/403 - 2s - loss: 11671824882466816.0000 - 2s/epoch - 5ms/step
# Epoch 91/100
# 403/403 - 3s - loss: 11667207792623616.0000 - 3s/epoch - 6ms/step
# Epoch 92/100
# 403/403 - 3s - loss: 11662563859234816.0000 - 3s/epoch - 7ms/step
# Epoch 93/100
# 403/403 - 2s - loss: 11657884492365824.0000 - 2s/epoch - 5ms/step
# Epoch 94/100
# 403/403 - 2s - loss: 11653184724402176.0000 - 2s/epoch - 5ms/step
# Epoch 95/100
# 403/403 - 2s - loss: 11648436638056448.0000 - 2s/epoch - 5ms/step
# Epoch 96/100
# 403/403 - 2s - loss: 11643658486939648.0000 - 2s/epoch - 5ms/step
# Epoch 97/100
# 403/403 - 2s - loss: 11638841681117184.0000 - 2s/epoch - 6ms/step
# Epoch 98/100
# 403/403 - 3s - loss: 11634002326716416.0000 - 3s/epoch - 8ms/step
# Epoch 99/100
# 403/403 - 2s - loss: 11629121096384512.0000 - 2s/epoch - 5ms/step
# Epoch 100/100
# 403/403 - 2s - loss: 11624187252703232.0000 - 2s/epoch - 5ms/step
# 13/13 [==============================] - 0s 3ms/step
# Directory 'saved_model' created
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Y_pred.shape (402, 1)
# Y_test.shape (402,)
# RSME:  161553244.62802887
# MAPE:  2.05523335691054
# Plot Prediction for %s Stock AAPL
# [*********************100%***********************]  1 of 1 completed
# Analysing Data for AMZN Stocks
#                Open     High      Low    Close  Adj Close    Volume
# Date
# 2015-01-02  15.6290  15.7375  15.3480  15.4260    15.4260  55664000
# 2015-01-05  15.3505  15.4190  15.0425  15.1095    15.1095  55484000
# 2015-01-06  15.1120  15.1500  14.6190  14.7645    14.7645  70380000
# 2015-01-07  14.8750  15.0640  14.7665  14.9210    14.9210  52806000
# 2015-01-08  15.0160  15.1570  14.8055  15.0230    15.0230  61768000
# Plotting Data for AMZN Stocks
# Data Preprocessing for AMZN Stocks
# Feature Scaling for  AMZN
# Train and Test Sets for Stock Price  AMZN
# (2013, 2, 5) (1611, 2, 5) (402, 2, 5) (402,)
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_23 (LSTM)              (None, 2, 50)             11200
#
#  lstm_24 (LSTM)              (None, 50)                20200
#
#  dense_9 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 31,451
# Trainable params: 31,451
# Non-trainable params: 0
# _________________________________________________________________
# Reshape training array to 2d
# Epoch 1/100
# 403/403 - 6s - loss: 8692068914298880.0000 - 6s/epoch - 15ms/step
# Epoch 2/100
# 403/403 - 2s - loss: 5264391343702016.0000 - 2s/epoch - 5ms/step
# Epoch 3/100
# 403/403 - 2s - loss: 3640318180196352.0000 - 2s/epoch - 5ms/step
# Epoch 4/100
# 403/403 - 2s - loss: 3591794981863424.0000 - 2s/epoch - 5ms/step
# Epoch 5/100
# 403/403 - 2s - loss: 3575932593897472.0000 - 2s/epoch - 5ms/step
# Epoch 6/100
# 403/403 - 3s - loss: 3576575765250048.0000 - 3s/epoch - 7ms/step
# Epoch 7/100
# 403/403 - 2s - loss: 3574259704135680.0000 - 2s/epoch - 6ms/step
# Epoch 8/100
# 403/403 - 2s - loss: 3572354617704448.0000 - 2s/epoch - 5ms/step
# Epoch 9/100
# 403/403 - 2s - loss: 3570850573844480.0000 - 2s/epoch - 5ms/step
# Epoch 10/100
# 403/403 - 2s - loss: 3569584632233984.0000 - 2s/epoch - 5ms/step
# Epoch 11/100
# 403/403 - 2s - loss: 3568462572027904.0000 - 2s/epoch - 5ms/step
# Epoch 12/100
# 403/403 - 2s - loss: 3567432048312320.0000 - 2s/epoch - 5ms/step
# Epoch 13/100
# 403/403 - 3s - loss: 3566462459445248.0000 - 3s/epoch - 7ms/step
# Epoch 14/100
# 403/403 - 2s - loss: 3565530988412928.0000 - 2s/epoch - 5ms/step
# Epoch 15/100
# 403/403 - 2s - loss: 3564625555619840.0000 - 2s/epoch - 4ms/step
# Epoch 16/100
# 403/403 - 2s - loss: 3563738913308672.0000 - 2s/epoch - 5ms/step
# Epoch 17/100
# 403/403 - 2s - loss: 3562864619028480.0000 - 2s/epoch - 5ms/step
# Epoch 18/100
# 403/403 - 2s - loss: 3561998377811968.0000 - 2s/epoch - 5ms/step
# Epoch 19/100
# 403/403 - 2s - loss: 3561136163127296.0000 - 2s/epoch - 6ms/step
# Epoch 20/100
# 403/403 - 3s - loss: 3560276632797184.0000 - 3s/epoch - 7ms/step
# Epoch 21/100
# 403/403 - 2s - loss: 3559421397434368.0000 - 2s/epoch - 5ms/step
# Epoch 22/100
# 403/403 - 2s - loss: 3558566430507008.0000 - 2s/epoch - 5ms/step
# Epoch 23/100
# 403/403 - 2s - loss: 3557710389837824.0000 - 2s/epoch - 5ms/step
# Epoch 24/100
# 403/403 - 2s - loss: 3556852201684992.0000 - 2s/epoch - 5ms/step
# Epoch 25/100
# 403/403 - 2s - loss: 3556000187547648.0000 - 2s/epoch - 5ms/step
# Epoch 26/100
# 403/403 - 3s - loss: 3555142536265728.0000 - 3s/epoch - 7ms/step
# Epoch 27/100
# 403/403 - 3s - loss: 3554285690290176.0000 - 3s/epoch - 7ms/step
# Epoch 28/100
# 403/403 - 3s - loss: 3553425623089152.0000 - 3s/epoch - 8ms/step
# Epoch 29/100
# 403/403 - 3s - loss: 3552565019017216.0000 - 3s/epoch - 8ms/step
# Epoch 30/100
# 403/403 - 2s - loss: 3551704146509824.0000 - 2s/epoch - 5ms/step
# Epoch 31/100
# 403/403 - 4s - loss: 3550842200260608.0000 - 4s/epoch - 10ms/step
# Epoch 32/100
# 403/403 - 2s - loss: 3549974348431360.0000 - 2s/epoch - 5ms/step
# Epoch 33/100
# 403/403 - 2s - loss: 3549108107214848.0000 - 2s/epoch - 5ms/step
# Epoch 34/100
# 403/403 - 2s - loss: 3548241865998336.0000 - 2s/epoch - 5ms/step
# Epoch 35/100
# 403/403 - 2s - loss: 3547370256072704.0000 - 2s/epoch - 6ms/step
# Epoch 36/100
# 403/403 - 2s - loss: 3546500793630720.0000 - 2s/epoch - 5ms/step
# Epoch 37/100
# 403/403 - 3s - loss: 3545624620302336.0000 - 3s/epoch - 7ms/step
# Epoch 38/100
# 403/403 - 3s - loss: 3544750326022144.0000 - 3s/epoch - 6ms/step
# Epoch 39/100
# 403/403 - 2s - loss: 3543873347387392.0000 - 2s/epoch - 5ms/step
# Epoch 40/100
# 403/403 - 2s - loss: 3542990463172608.0000 - 2s/epoch - 5ms/step
# Epoch 41/100
# 403/403 - 2s - loss: 3542108115828736.0000 - 2s/epoch - 5ms/step
# Epoch 42/100
# 403/403 - 2s - loss: 3541222547259392.0000 - 2s/epoch - 5ms/step
# Epoch 43/100
# 403/403 - 2s - loss: 3540337247125504.0000 - 2s/epoch - 5ms/step
# Epoch 44/100
# 403/403 - 3s - loss: 3539448725766144.0000 - 3s/epoch - 8ms/step
# Epoch 45/100
# 403/403 - 2s - loss: 3538555372568576.0000 - 2s/epoch - 5ms/step
# Epoch 46/100
# 403/403 - 2s - loss: 3537660677193728.0000 - 2s/epoch - 5ms/step
# Epoch 47/100
# 403/403 - 2s - loss: 3536760076238848.0000 - 2s/epoch - 5ms/step
# Epoch 48/100
# 403/403 - 2s - loss: 3535861891203072.0000 - 2s/epoch - 5ms/step
# Epoch 49/100
# 403/403 - 2s - loss: 3534959142764544.0000 - 2s/epoch - 5ms/step
# Epoch 50/100
# 403/403 - 3s - loss: 3534053173100544.0000 - 3s/epoch - 7ms/step
# Epoch 51/100
# 403/403 - 2s - loss: 3533146398130176.0000 - 2s/epoch - 6ms/step
# Epoch 52/100
# 403/403 - 2s - loss: 3532231838531584.0000 - 2s/epoch - 5ms/step
# Epoch 53/100
# 403/403 - 2s - loss: 3531317010497536.0000 - 2s/epoch - 5ms/step
# Epoch 54/100
# 403/403 - 2s - loss: 3530398424367104.0000 - 2s/epoch - 5ms/step
# Epoch 55/100
# 403/403 - 2s - loss: 3529477690753024.0000 - 2s/epoch - 5ms/step
# Epoch 56/100
# 403/403 - 2s - loss: 3528550246252544.0000 - 2s/epoch - 6ms/step
# Epoch 57/100
# 403/403 - 3s - loss: 3527623338622976.0000 - 3s/epoch - 7ms/step
# Epoch 58/100
# 403/403 - 2s - loss: 3526693478203392.0000 - 2s/epoch - 5ms/step
# Epoch 59/100
# 403/403 - 2s - loss: 3525755564720128.0000 - 2s/epoch - 5ms/step
# Epoch 60/100
# 403/403 - 2s - loss: 3524816577495040.0000 - 2s/epoch - 5ms/step
# Epoch 61/100
# 403/403 - 2s - loss: 3523875442786304.0000 - 2s/epoch - 5ms/step
# Epoch 62/100
# 403/403 - 2s - loss: 3522927060320256.0000 - 2s/epoch - 6ms/step
# Epoch 63/100
# 403/403 - 3s - loss: 3521974919757824.0000 - 3s/epoch - 8ms/step
# Epoch 64/100
# 403/403 - 2s - loss: 3521019021099008.0000 - 2s/epoch - 5ms/step
# Epoch 65/100
# 403/403 - 2s - loss: 3520059901214720.0000 - 2s/epoch - 4ms/step
# Epoch 66/100
# 403/403 - 2s - loss: 3519096754798592.0000 - 2s/epoch - 4ms/step
# Epoch 67/100
# 403/403 - 2s - loss: 3518127434366976.0000 - 2s/epoch - 4ms/step
# Epoch 68/100
# 403/403 - 2s - loss: 3517159456112640.0000 - 2s/epoch - 5ms/step
# Epoch 69/100
# 403/403 - 2s - loss: 3516180472004608.0000 - 2s/epoch - 5ms/step
# Epoch 70/100
# 403/403 - 3s - loss: 3515199071977472.0000 - 3s/epoch - 7ms/step
# Epoch 71/100
# 403/403 - 2s - loss: 3514213645418496.0000 - 2s/epoch - 5ms/step
# Epoch 72/100
# 403/403 - 2s - loss: 3513222313279488.0000 - 2s/epoch - 5ms/step
# Epoch 73/100
# 403/403 - 2s - loss: 3512225880866816.0000 - 2s/epoch - 5ms/step
# Epoch 74/100
# 403/403 - 2s - loss: 3511224616615936.0000 - 2s/epoch - 5ms/step
# Epoch 75/100
# 403/403 - 2s - loss: 3510218788962304.0000 - 2s/epoch - 5ms/step
# Epoch 76/100
# 403/403 - 3s - loss: 3509208129470464.0000 - 3s/epoch - 7ms/step
# Epoch 77/100
# 403/403 - 3s - loss: 3508192906575872.0000 - 3s/epoch - 6ms/step
# Epoch 78/100
# 403/403 - 2s - loss: 3507166946263040.0000 - 2s/epoch - 5ms/step
# Epoch 79/100
# 403/403 - 2s - loss: 3506138570031104.0000 - 2s/epoch - 5ms/step
# Epoch 80/100
# 403/403 - 2s - loss: 3505106972573696.0000 - 2s/epoch - 5ms/step
# Epoch 81/100
# 403/403 - 2s - loss: 3504068127358976.0000 - 2s/epoch - 5ms/step
# Epoch 82/100
# 403/403 - 2s - loss: 3503023644999680.0000 - 2s/epoch - 6ms/step
# Epoch 83/100
# 403/403 - 3s - loss: 3501971378012160.0000 - 3s/epoch - 7ms/step
# Epoch 84/100
# 403/403 - 2s - loss: 3500912668573696.0000 - 2s/epoch - 5ms/step
# Epoch 85/100
# 403/403 - 2s - loss: 3499847516684288.0000 - 2s/epoch - 5ms/step
# Epoch 86/100
# 403/403 - 2s - loss: 3498775117037568.0000 - 2s/epoch - 5ms/step
# Epoch 87/100
# 403/403 - 2s - loss: 3497698690859008.0000 - 2s/epoch - 5ms/step
# Epoch 88/100
# 403/403 - 2s - loss: 3496616895971328.0000 - 2s/epoch - 6ms/step
# Epoch 89/100
# 403/403 - 3s - loss: 3495523558359040.0000 - 3s/epoch - 8ms/step
# Epoch 90/100
# 403/403 - 2s - loss: 3494425388908544.0000 - 2s/epoch - 5ms/step
# Epoch 91/100
# 403/403 - 2s - loss: 3493319971700736.0000 - 2s/epoch - 5ms/step
# Epoch 92/100
# 403/403 - 2s - loss: 3492207306735616.0000 - 2s/epoch - 5ms/step
# Epoch 93/100
# 403/403 - 2s - loss: 3491085246529536.0000 - 2s/epoch - 5ms/step
# Epoch 94/100
# 403/403 - 2s - loss: 3489960501968896.0000 - 2s/epoch - 5ms/step
# Epoch 95/100
# 403/403 - 3s - loss: 3488823409377280.0000 - 3s/epoch - 7ms/step
# Epoch 96/100
# 403/403 - 2s - loss: 3487677189980160.0000 - 2s/epoch - 6ms/step
# Epoch 97/100
# 403/403 - 2s - loss: 3486523991261184.0000 - 2s/epoch - 5ms/step
# Epoch 98/100
# 403/403 - 2s - loss: 3485364618526720.0000 - 2s/epoch - 5ms/step
# Epoch 99/100
# 403/403 - 2s - loss: 3484196118986752.0000 - 2s/epoch - 5ms/step
# Epoch 100/100
# 403/403 - 2s - loss: 3483020371689472.0000 - 2s/epoch - 5ms/step
# 13/13 [==============================] - 1s 3ms/step
# Directory 'saved_model' created
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Y_pred.shape (402, 1)
# Y_test.shape (402,)
# RSME:  50237339.21627417
# MAPE:  0.7309412695697268
# Plot Prediction for %s Stock AMZN
# [*********************100%***********************]  1 of 1 completed
# Analysing Data for GOOG Stocks
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-01-02  26.378078  26.490770  26.133251  26.168653  26.168653  28951268
# 2015-01-05  26.091366  26.144720  25.582764  25.623152  25.623152  41196796
# 2015-01-06  25.679497  25.738087  24.983908  25.029282  25.029282  57998800
# 2015-01-07  25.280592  25.292759  24.914099  24.986401  24.986401  41301082
# 2015-01-08  24.831326  25.105074  24.482782  25.065184  25.065184  67071641
# Plotting Data for GOOG Stocks
# Data Preprocessing for GOOG Stocks
# Feature Scaling for  GOOG
# Train and Test Sets for Stock Price  GOOG
# (2013, 2, 5) (1611, 2, 5) (402, 2, 5) (402,)
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_25 (LSTM)              (None, 2, 50)             11200
#
#  lstm_26 (LSTM)              (None, 50)                20200
#
#  dense_10 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 31,451
# Trainable params: 31,451
# Non-trainable params: 0
# _________________________________________________________________
# Reshape training array to 2d
# Epoch 1/100
# 403/403 - 6s - loss: 1364478226595840.0000 - 6s/epoch - 15ms/step
# Epoch 2/100
# 403/403 - 2s - loss: 686006269378560.0000 - 2s/epoch - 6ms/step
# Epoch 3/100
# 403/403 - 2s - loss: 489189057495040.0000 - 2s/epoch - 5ms/step
# Epoch 4/100
# 403/403 - 2s - loss: 483857459576832.0000 - 2s/epoch - 5ms/step
# Epoch 5/100
# 403/403 - 2s - loss: 482334826561536.0000 - 2s/epoch - 4ms/step
# Epoch 6/100
# 403/403 - 2s - loss: 481592803852288.0000 - 2s/epoch - 4ms/step
# Epoch 7/100
# 403/403 - 2s - loss: 481145825263616.0000 - 2s/epoch - 4ms/step
# Epoch 8/100
# 403/403 - 3s - loss: 480839305527296.0000 - 3s/epoch - 7ms/step
# Epoch 9/100
# 403/403 - 2s - loss: 480610162311168.0000 - 2s/epoch - 6ms/step
# Epoch 10/100
# 403/403 - 2s - loss: 480425612935168.0000 - 2s/epoch - 5ms/step
# Epoch 11/100
# 403/403 - 2s - loss: 480269987479552.0000 - 2s/epoch - 5ms/step
# Epoch 12/100
# 403/403 - 2s - loss: 480133051842560.0000 - 2s/epoch - 5ms/step
# Epoch 13/100
# 403/403 - 2s - loss: 480008330018816.0000 - 2s/epoch - 5ms/step
# Epoch 14/100
# 403/403 - 3s - loss: 479892164575232.0000 - 3s/epoch - 7ms/step
# Epoch 15/100
# 403/403 - 3s - loss: 479781971820544.0000 - 3s/epoch - 7ms/step
# Epoch 16/100
# 403/403 - 2s - loss: 479675604271104.0000 - 2s/epoch - 5ms/step
# Epoch 17/100
# 403/403 - 2s - loss: 479572256620544.0000 - 2s/epoch - 5ms/step
# Epoch 18/100
# 403/403 - 2s - loss: 479471022899200.0000 - 2s/epoch - 6ms/step
# Epoch 19/100
# 403/403 - 2s - loss: 479371030691840.0000 - 2s/epoch - 5ms/step
# Epoch 20/100
# 403/403 - 3s - loss: 479271743127552.0000 - 3s/epoch - 8ms/step
# Epoch 21/100
# 403/403 - 3s - loss: 479173193760768.0000 - 3s/epoch - 6ms/step
# Epoch 22/100
# 403/403 - 2s - loss: 479075047047168.0000 - 2s/epoch - 5ms/step
# Epoch 23/100
# 403/403 - 2s - loss: 478977437204480.0000 - 2s/epoch - 5ms/step
# Epoch 24/100
# 403/403 - 2s - loss: 478879961579520.0000 - 2s/epoch - 5ms/step
# Epoch 25/100
# 403/403 - 2s - loss: 478781781311488.0000 - 2s/epoch - 5ms/step
# Epoch 26/100
# 403/403 - 3s - loss: 478684439904256.0000 - 3s/epoch - 8ms/step
# Epoch 27/100
# 403/403 - 3s - loss: 478587400486912.0000 - 3s/epoch - 7ms/step
# Epoch 28/100
# 403/403 - 2s - loss: 478489589317632.0000 - 2s/epoch - 5ms/step
# Epoch 29/100
# 403/403 - 2s - loss: 478391643930624.0000 - 2s/epoch - 5ms/step
# Epoch 30/100
# 403/403 - 2s - loss: 478293799206912.0000 - 2s/epoch - 5ms/step
# Epoch 31/100
# 403/403 - 2s - loss: 478196055146496.0000 - 2s/epoch - 5ms/step
# Epoch 32/100
# 403/403 - 3s - loss: 478097908432896.0000 - 3s/epoch - 8ms/step
# Epoch 33/100
# 403/403 - 2s - loss: 477999996600320.0000 - 2s/epoch - 6ms/step
# Epoch 34/100
# 403/403 - 2s - loss: 477901715668992.0000 - 2s/epoch - 5ms/step
# Epoch 35/100
# 403/403 - 2s - loss: 477803434737664.0000 - 2s/epoch - 5ms/step
# Epoch 36/100
# 403/403 - 2s - loss: 477704583380992.0000 - 2s/epoch - 5ms/step
# Epoch 37/100
# 403/403 - 2s - loss: 477606067568640.0000 - 2s/epoch - 5ms/step
# Epoch 38/100
# 403/403 - 3s - loss: 477506780004352.0000 - 3s/epoch - 8ms/step
# Epoch 39/100
# 403/403 - 3s - loss: 477407827984384.0000 - 3s/epoch - 6ms/step
# Epoch 40/100
# 403/403 - 2s - loss: 477308775301120.0000 - 2s/epoch - 5ms/step
# Epoch 41/100
# 403/403 - 2s - loss: 477209588400128.0000 - 2s/epoch - 5ms/step
# Epoch 42/100
# 403/403 - 2s - loss: 477109763964928.0000 - 2s/epoch - 5ms/step
# Epoch 43/100
# 403/403 - 2s - loss: 477010073747456.0000 - 2s/epoch - 5ms/step
# Epoch 44/100
# 403/403 - 3s - loss: 476910349975552.0000 - 3s/epoch - 8ms/step
# Epoch 45/100
# 403/403 - 2s - loss: 476809720233984.0000 - 2s/epoch - 6ms/step
# Epoch 46/100
# 403/403 - 2s - loss: 476709056937984.0000 - 2s/epoch - 5ms/step
# Epoch 47/100
# 403/403 - 2s - loss: 476608863404032.0000 - 2s/epoch - 5ms/step
# Epoch 48/100
# 403/403 - 2s - loss: 476507663237120.0000 - 2s/epoch - 5ms/step
# Epoch 49/100
# 403/403 - 2s - loss: 476406597287936.0000 - 2s/epoch - 5ms/step
# Epoch 50/100
# 403/403 - 3s - loss: 476305397121024.0000 - 3s/epoch - 7ms/step
# Epoch 51/100
# 403/403 - 3s - loss: 476203861409792.0000 - 3s/epoch - 6ms/step
# Epoch 52/100
# 403/403 - 2s - loss: 476102023708672.0000 - 2s/epoch - 5ms/step
# Epoch 53/100
# 403/403 - 2s - loss: 475999816908800.0000 - 2s/epoch - 5ms/step
# Epoch 54/100
# 403/403 - 2s - loss: 475897509445632.0000 - 2s/epoch - 5ms/step
# Epoch 55/100
# 403/403 - 2s - loss: 475794765774848.0000 - 2s/epoch - 5ms/step
# Epoch 56/100
# 403/403 - 3s - loss: 475691686559744.0000 - 3s/epoch - 7ms/step
# Epoch 57/100
# 403/403 - 3s - loss: 475588573790208.0000 - 3s/epoch - 7ms/step
# Epoch 58/100
# 403/403 - 2s - loss: 475484857040896.0000 - 2s/epoch - 5ms/step
# Epoch 59/100
# 403/403 - 2s - loss: 475381173846016.0000 - 2s/epoch - 5ms/step
# Epoch 60/100
# 403/403 - 2s - loss: 475277087997952.0000 - 2s/epoch - 5ms/step
# Epoch 61/100
# 403/403 - 2s - loss: 475172666605568.0000 - 2s/epoch - 5ms/step
# Epoch 62/100
# 403/403 - 3s - loss: 475067607678976.0000 - 3s/epoch - 7ms/step
# Epoch 63/100
# 403/403 - 3s - loss: 474962750078976.0000 - 3s/epoch - 7ms/step
# Epoch 64/100
# 403/403 - 2s - loss: 474857456271360.0000 - 2s/epoch - 5ms/step
# Epoch 65/100
# 403/403 - 2s - loss: 474751457820672.0000 - 2s/epoch - 5ms/step
# Epoch 66/100
# 403/403 - 2s - loss: 474645291597824.0000 - 2s/epoch - 5ms/step
# Epoch 67/100
# 403/403 - 2s - loss: 474539226038272.0000 - 2s/epoch - 5ms/step
# Epoch 68/100
# 403/403 - 3s - loss: 474431851855872.0000 - 3s/epoch - 7ms/step
# Epoch 69/100
# 403/403 - 3s - loss: 474324645445632.0000 - 3s/epoch - 7ms/step
# Epoch 70/100
# 403/403 - 2s - loss: 474217405480960.0000 - 2s/epoch - 5ms/step
# Epoch 71/100
# 403/403 - 2s - loss: 474109158883328.0000 - 2s/epoch - 6ms/step
# Epoch 72/100
# 403/403 - 2s - loss: 474000677404672.0000 - 2s/epoch - 6ms/step
# Epoch 73/100
# 403/403 - 2s - loss: 473892128817152.0000 - 2s/epoch - 6ms/step
# Epoch 74/100
# 403/403 - 4s - loss: 473782640705536.0000 - 4s/epoch - 9ms/step
# Epoch 75/100
# 403/403 - 2s - loss: 473672984821760.0000 - 2s/epoch - 5ms/step
# Epoch 76/100
# 403/403 - 2s - loss: 473563060502528.0000 - 2s/epoch - 5ms/step
# Epoch 77/100
# 403/403 - 2s - loss: 473452297322496.0000 - 2s/epoch - 5ms/step
# Epoch 78/100
# 403/403 - 2s - loss: 473341701914624.0000 - 2s/epoch - 5ms/step
# Epoch 79/100
# 403/403 - 3s - loss: 473230200537088.0000 - 3s/epoch - 7ms/step
# Epoch 80/100
# 403/403 - 3s - loss: 473117994516480.0000 - 3s/epoch - 8ms/step
# Epoch 81/100
# 403/403 - 2s - loss: 473005486505984.0000 - 2s/epoch - 5ms/step
# Epoch 82/100
# 403/403 - 2s - loss: 472892877832192.0000 - 2s/epoch - 5ms/step
# Epoch 83/100
# 403/403 - 2s - loss: 472779296079872.0000 - 2s/epoch - 5ms/step
# Epoch 84/100
# 403/403 - 2s - loss: 472665479446528.0000 - 2s/epoch - 5ms/step
# Epoch 85/100
# 403/403 - 2s - loss: 472551025278976.0000 - 2s/epoch - 6ms/step
# Epoch 86/100
# 403/403 - 3s - loss: 472436168458240.0000 - 3s/epoch - 8ms/step
# Epoch 87/100
# 403/403 - 2s - loss: 472320741212160.0000 - 2s/epoch - 5ms/step
# Epoch 88/100
# 403/403 - 2s - loss: 472204609323008.0000 - 2s/epoch - 5ms/step
# Epoch 89/100
# 403/403 - 2s - loss: 472088276107264.0000 - 2s/epoch - 5ms/step
# Epoch 90/100
# 403/403 - 2s - loss: 471970969812992.0000 - 2s/epoch - 5ms/step
# Epoch 91/100
# 403/403 - 2s - loss: 471853093093376.0000 - 2s/epoch - 5ms/step
# Epoch 92/100
# 403/403 - 3s - loss: 471734813720576.0000 - 3s/epoch - 8ms/step
# Epoch 93/100
# 403/403 - 2s - loss: 471615594823680.0000 - 2s/epoch - 6ms/step
# Epoch 94/100
# 403/403 - 2s - loss: 471496006828032.0000 - 2s/epoch - 5ms/step
# Epoch 95/100
# 403/403 - 2s - loss: 471376284614656.0000 - 2s/epoch - 5ms/step
# Epoch 96/100
# 403/403 - 2s - loss: 471255421550592.0000 - 2s/epoch - 5ms/step
# Epoch 97/100
# 403/403 - 2s - loss: 471134021615616.0000 - 2s/epoch - 5ms/step
# Epoch 98/100
# 403/403 - 3s - loss: 471011917037568.0000 - 3s/epoch - 7ms/step
# Epoch 99/100
# 403/403 - 3s - loss: 470889443360768.0000 - 3s/epoch - 6ms/step
# Epoch 100/100
# 403/403 - 2s - loss: 470765627506688.0000 - 2s/epoch - 5ms/step
# 13/13 [==============================] - 0s 3ms/step
# Directory 'saved_model' created
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Y_pred.shape (402, 1)
# Y_test.shape (402,)
# RSME:  32552347.951705847
# MAPE:  1.4332054765007796
# Plot Prediction for %s Stock GOOG
# [*********************100%***********************]  1 of 1 completed
# Analysing Data for MSFT Stocks
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-01-02  46.660000  47.419998  46.540001  46.759998  40.811424  27913900
# 2015-01-05  46.369999  46.730000  46.250000  46.330002  40.436131  39673900
# 2015-01-06  46.380001  46.750000  45.540001  45.650002  39.842632  36447900
# 2015-01-07  45.980000  46.459999  45.490002  46.230000  40.348862  29114100
# 2015-01-08  46.750000  47.750000  46.720001  47.590000  41.535843  29645200
# Plotting Data for MSFT Stocks
# Data Preprocessing for MSFT Stocks
# Feature Scaling for  MSFT
# Train and Test Sets for Stock Price  MSFT
# (2013, 2, 5) (1611, 2, 5) (402, 2, 5) (402,)
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_27 (LSTM)              (None, 2, 50)             11200
#
#  lstm_28 (LSTM)              (None, 50)                20200
#
#  dense_11 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 31,451
# Trainable params: 31,451
# Non-trainable params: 0
# _________________________________________________________________
# Reshape training array to 2d
# Epoch 1/100
# 403/403 - 6s - loss: 962022678200320.0000 - 6s/epoch - 15ms/step
# Epoch 2/100
# 403/403 - 2s - loss: 491015660109824.0000 - 2s/epoch - 5ms/step
# Epoch 3/100
# 403/403 - 2s - loss: 442881424752640.0000 - 2s/epoch - 5ms/step
# Epoch 4/100
# 403/403 - 2s - loss: 442314388406272.0000 - 2s/epoch - 5ms/step
# Epoch 5/100
# 403/403 - 2s - loss: 441883549499392.0000 - 2s/epoch - 5ms/step
# Epoch 6/100
# 403/403 - 2s - loss: 441619509673984.0000 - 2s/epoch - 6ms/step
# Epoch 7/100
# 403/403 - 3s - loss: 441423048474624.0000 - 3s/epoch - 7ms/step
# Epoch 8/100
# 403/403 - 2s - loss: 441258195550208.0000 - 2s/epoch - 5ms/step
# Epoch 9/100
# 403/403 - 2s - loss: 441110891593728.0000 - 2s/epoch - 5ms/step
# Epoch 10/100
# 403/403 - 2s - loss: 440972781551616.0000 - 2s/epoch - 5ms/step
# Epoch 11/100
# 403/403 - 2s - loss: 440841550168064.0000 - 2s/epoch - 5ms/step
# Epoch 12/100
# 403/403 - 2s - loss: 440713942663168.0000 - 2s/epoch - 5ms/step
# Epoch 13/100
# 403/403 - 3s - loss: 440589287948288.0000 - 3s/epoch - 7ms/step
# Epoch 14/100
# 403/403 - 2s - loss: 440466579390464.0000 - 2s/epoch - 6ms/step
# Epoch 15/100
# 403/403 - 2s - loss: 440344340594688.0000 - 2s/epoch - 5ms/step
# Epoch 16/100
# 403/403 - 2s - loss: 440223309758464.0000 - 2s/epoch - 5ms/step
# Epoch 17/100
# 403/403 - 2s - loss: 440103252000768.0000 - 2s/epoch - 5ms/step
# Epoch 18/100
# 403/403 - 2s - loss: 439982825144320.0000 - 2s/epoch - 5ms/step
# Epoch 19/100
# 403/403 - 3s - loss: 439862834495488.0000 - 3s/epoch - 6ms/step
# Epoch 20/100
# 403/403 - 3s - loss: 439743112282112.0000 - 3s/epoch - 7ms/step
# Epoch 21/100
# 403/403 - 2s - loss: 439622752534528.0000 - 2s/epoch - 5ms/step
# Epoch 22/100
# 403/403 - 2s - loss: 439502728331264.0000 - 2s/epoch - 5ms/step
# Epoch 23/100
# 403/403 - 2s - loss: 439382536355840.0000 - 2s/epoch - 5ms/step
# Epoch 24/100
# 403/403 - 2s - loss: 439262143053824.0000 - 2s/epoch - 5ms/step
# Epoch 25/100
# 403/403 - 2s - loss: 439141347098624.0000 - 2s/epoch - 5ms/step
# Epoch 26/100
# 403/403 - 3s - loss: 439020685361152.0000 - 3s/epoch - 7ms/step
# Epoch 27/100
# 403/403 - 2s - loss: 438899721633792.0000 - 2s/epoch - 5ms/step
# Epoch 28/100
# 403/403 - 2s - loss: 438778422362112.0000 - 2s/epoch - 5ms/step
# Epoch 29/100
# 403/403 - 2s - loss: 438656753991680.0000 - 2s/epoch - 5ms/step
# Epoch 30/100
# 403/403 - 2s - loss: 438534716522496.0000 - 2s/epoch - 5ms/step
# Epoch 31/100
# 403/403 - 2s - loss: 438412309954560.0000 - 2s/epoch - 5ms/step
# Epoch 32/100
# 403/403 - 3s - loss: 438289802723328.0000 - 3s/epoch - 6ms/step
# Epoch 33/100
# 403/403 - 3s - loss: 438166590849024.0000 - 3s/epoch - 7ms/step
# Epoch 34/100
# 403/403 - 2s - loss: 438043211202560.0000 - 2s/epoch - 5ms/step
# Epoch 35/100
# 403/403 - 2s - loss: 437919663783936.0000 - 2s/epoch - 5ms/step
# Epoch 36/100
# 403/403 - 2s - loss: 437795411722240.0000 - 2s/epoch - 5ms/step
# Epoch 37/100
# 403/403 - 2s - loss: 437670757007360.0000 - 2s/epoch - 5ms/step
# Epoch 38/100
# 403/403 - 2s - loss: 437545900965888.0000 - 2s/epoch - 6ms/step
# Epoch 39/100
# 403/403 - 3s - loss: 437420575162368.0000 - 3s/epoch - 7ms/step
# Epoch 40/100
# 403/403 - 2s - loss: 437294611824640.0000 - 2s/epoch - 5ms/step
# Epoch 41/100
# 403/403 - 2s - loss: 437168312942592.0000 - 2s/epoch - 5ms/step
# Epoch 42/100
# 403/403 - 2s - loss: 437041745625088.0000 - 2s/epoch - 5ms/step
# Epoch 43/100
# 403/403 - 2s - loss: 436914373001216.0000 - 2s/epoch - 5ms/step
# Epoch 44/100
# 403/403 - 2s - loss: 436786463506432.0000 - 2s/epoch - 5ms/step
# Epoch 45/100
# 403/403 - 3s - loss: 436658050695168.0000 - 3s/epoch - 7ms/step
# Epoch 46/100
# 403/403 - 2s - loss: 436529235230720.0000 - 2s/epoch - 6ms/step
# Epoch 47/100
# 403/403 - 2s - loss: 436399547351040.0000 - 2s/epoch - 5ms/step
# Epoch 48/100
# 403/403 - 2s - loss: 436269758808064.0000 - 2s/epoch - 5ms/step
# Epoch 49/100
# 403/403 - 2s - loss: 436138795859968.0000 - 2s/epoch - 5ms/step
# Epoch 50/100
# 403/403 - 2s - loss: 436007598030848.0000 - 2s/epoch - 5ms/step
# Epoch 51/100
# 403/403 - 3s - loss: 435875662004224.0000 - 3s/epoch - 6ms/step
# Epoch 52/100
# 403/403 - 3s - loss: 435743423987712.0000 - 3s/epoch - 7ms/step
# Epoch 53/100
# 403/403 - 2s - loss: 435609978011648.0000 - 2s/epoch - 5ms/step
# Epoch 54/100
# 403/403 - 2s - loss: 435475961610240.0000 - 2s/epoch - 5ms/step
# Epoch 55/100
# 403/403 - 2s - loss: 435341173456896.0000 - 2s/epoch - 5ms/step
# Epoch 56/100
# 403/403 - 2s - loss: 435205680660480.0000 - 2s/epoch - 5ms/step
# Epoch 57/100
# 403/403 - 2s - loss: 435069617438720.0000 - 2s/epoch - 5ms/step
# Epoch 58/100
# 403/403 - 3s - loss: 434932816019456.0000 - 3s/epoch - 8ms/step
# Epoch 59/100
# 403/403 - 2s - loss: 434795578392576.0000 - 2s/epoch - 5ms/step
# Epoch 60/100
# 403/403 - 2s - loss: 434657334132736.0000 - 2s/epoch - 6ms/step
# Epoch 61/100
# 403/403 - 2s - loss: 434517915467776.0000 - 2s/epoch - 5ms/step
# Epoch 62/100
# 403/403 - 2s - loss: 434378060595200.0000 - 2s/epoch - 5ms/step
# Epoch 63/100
# 403/403 - 2s - loss: 434236762882048.0000 - 2s/epoch - 5ms/step
# Epoch 64/100
# 403/403 - 3s - loss: 434094861189120.0000 - 3s/epoch - 7ms/step
# Epoch 65/100
# 403/403 - 2s - loss: 433951650873344.0000 - 2s/epoch - 6ms/step
# Epoch 66/100
# 403/403 - 2s - loss: 433806595063808.0000 - 2s/epoch - 5ms/step
# Epoch 67/100
# 403/403 - 2s - loss: 433659727314944.0000 - 2s/epoch - 5ms/step
# Epoch 68/100
# 403/403 - 2s - loss: 433511886487552.0000 - 2s/epoch - 5ms/step
# Epoch 69/100
# 403/403 - 2s - loss: 433363609452544.0000 - 2s/epoch - 5ms/step
# Epoch 70/100
# 403/403 - 2s - loss: 433214627774464.0000 - 2s/epoch - 6ms/step
# Epoch 71/100
# 403/403 - 3s - loss: 433064975007744.0000 - 3s/epoch - 7ms/step
# Epoch 72/100
# 403/403 - 2s - loss: 432913812291584.0000 - 2s/epoch - 5ms/step
# Epoch 73/100
# 403/403 - 2s - loss: 432761743605760.0000 - 2s/epoch - 5ms/step
# Epoch 74/100
# 403/403 - 2s - loss: 432608232079360.0000 - 2s/epoch - 5ms/step
# Epoch 75/100
# 403/403 - 2s - loss: 432453579702272.0000 - 2s/epoch - 5ms/step
# Epoch 76/100
# 403/403 - 2s - loss: 432298491117568.0000 - 2s/epoch - 5ms/step
# Epoch 77/100
# 403/403 - 3s - loss: 432140885950464.0000 - 3s/epoch - 7ms/step
# Epoch 78/100
# 403/403 - 2s - loss: 431982475476992.0000 - 2s/epoch - 6ms/step
# Epoch 79/100
# 403/403 - 2s - loss: 431815139524608.0000 - 2s/epoch - 5ms/step
# Epoch 80/100
# 403/403 - 2s - loss: 431669983051776.0000 - 2s/epoch - 5ms/step
# Epoch 81/100
# 403/403 - 2s - loss: 431500969377792.0000 - 2s/epoch - 5ms/step
# Epoch 82/100
# 403/403 - 2s - loss: 431334640058368.0000 - 2s/epoch - 5ms/step
# Epoch 83/100
# 403/403 - 3s - loss: 431168981827584.0000 - 3s/epoch - 7ms/step
# Epoch 84/100
# 403/403 - 3s - loss: 431002551844864.0000 - 3s/epoch - 7ms/step
# Epoch 85/100
# 403/403 - 2s - loss: 430832565092352.0000 - 2s/epoch - 5ms/step
# Epoch 86/100
# 403/403 - 2s - loss: 430664155398144.0000 - 2s/epoch - 5ms/step
# Epoch 87/100
# 403/403 - 2s - loss: 430490242777088.0000 - 2s/epoch - 5ms/step
# Epoch 88/100
# 403/403 - 2s - loss: 430318242758656.0000 - 2s/epoch - 5ms/step
# Epoch 89/100
# 403/403 - 3s - loss: 430142887297024.0000 - 3s/epoch - 7ms/step
# Epoch 90/100
# 403/403 - 3s - loss: 429963975065600.0000 - 3s/epoch - 7ms/step
# Epoch 91/100
# 403/403 - 2s - loss: 429786807664640.0000 - 2s/epoch - 5ms/step
# Epoch 92/100
# 403/403 - 2s - loss: 429603499802624.0000 - 2s/epoch - 5ms/step
# Epoch 93/100
# 403/403 - 2s - loss: 429403951595520.0000 - 2s/epoch - 5ms/step
# Epoch 94/100
# 403/403 - 2s - loss: 429244333162496.0000 - 2s/epoch - 5ms/step
# Epoch 95/100
# 403/403 - 2s - loss: 429053609771008.0000 - 2s/epoch - 6ms/step
# Epoch 96/100
# 403/403 - 3s - loss: 428863758794752.0000 - 3s/epoch - 8ms/step
# Epoch 97/100
# 403/403 - 2s - loss: 428671793889280.0000 - 2s/epoch - 5ms/step
# Epoch 98/100
# 403/403 - 2s - loss: 428477849272320.0000 - 2s/epoch - 5ms/step
# Epoch 99/100
# 403/403 - 2s - loss: 428282394705920.0000 - 2s/epoch - 5ms/step
# Epoch 100/100
# 403/403 - 2s - loss: 428084289339392.0000 - 2s/epoch - 5ms/step
# 13/13 [==============================] - 1s 7ms/step
# Directory 'saved_model' created
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Y_pred.shape (402, 1)
# Y_test.shape (402,)
# RSME:  21732605.224303
# MAPE:  0.8463402448467734
# Plot Prediction for %s Stock MSFT
